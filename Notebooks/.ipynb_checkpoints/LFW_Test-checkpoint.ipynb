# %%
import os
os.chdir('..')
print(os.getcwd())
from Code.dataloaders import LFWContrastiveDataset
from Code.trainers import Trainer
from Code.models import ContrastiveModel
from Code.losses import ContrastiveLoss
# Out:
# E:\Research\ContrastiveLearning

# %%
import torchsummary

# %%
l = LFWContrastiveDataset(resize_to=(105,105))

# %%
#l.__len__()

# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2

outdict = l.__getitem__(4)

# %%
[outdict[k].shape for k in outdict.keys()]
# Out:
# [torch.Size([3, 3, 105, 105]),
#  torch.Size([3, 3, 105, 105]),
#  torch.Size([3, 1])]

# %%
idx = 0
plt.imshow(outdict["x1"][idx,0,...])

# %%
plt.imshow(outdict["x2"][idx,0,...])

# %% [markdown]
# ## Model
# --------------

# %%
DEVICE = 'cuda'
IN_CHANNELS = 3
EMB_SIZE = 4096

model = ContrastiveModel(IN_CHANNELS, EMB_SIZE).to(DEVICE)
model
torchsummary.summary(model, input_size = (3, 105, 105), device=DEVICE)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 96, 96]          19,264
#               ReLU-2           [-1, 64, 96, 96]               0
#          MaxPool2d-3           [-1, 64, 48, 48]               0
#             Conv2d-4          [-1, 128, 42, 42]         401,536
#               ReLU-5          [-1, 128, 42, 42]               0
#          MaxPool2d-6          [-1, 128, 21, 21]               0
#             Conv2d-7          [-1, 128, 18, 18]         262,272
#          MaxPool2d-8            [-1, 128, 9, 9]               0
#               ReLU-9            [-1, 128, 9, 9]               0
#            Conv2d-10            [-1, 256, 6, 6]         524,544
#              ReLU-11            [-1, 256, 6, 6]               0
#            Linear-12                 [-1, 4096]      37,752,832
# ================================================================
# Total params: 38,960,448
# Trainable params: 38,960,448
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.13
# Forward/backward pass size (MB): 14.65
# Params size (MB): 148.62
# Estimated Total Size (MB): 163.40
# ----------------------------------------------------------------

# %%
lfw = LFWContrastiveDataset(data_path = './Data/Train/', resize_to=(105,105))

import torch
from torch.utils.data.sampler import SubsetRandomSampler
subset_indices = list(range(200))
lfw_dl = torch.utils.data.DataLoader(lfw, batch_size=None, sampler=SubsetRandomSampler(subset_indices))

M = ContrastiveModel(in_channels=3)

# %%
t = Trainer(model = M, dataloader = lfw_dl, 
            lr=0.0005, 
            loss_function=ContrastiveLoss())

# %%
def make_writer(name, log_folder='Outputs\Tensorboard'):
    '''
    Create a TensorboardX writer object given an experiment name and a log folder
    '''
    import time 
    import os
    from tensorboardX import SummaryWriter
    import shutil
    
    dir_name = os.path.join(log_folder, name)
    if not os.path.exists(dir_name):
        os.mkdir(dir_name)
    else:
        print("Warning: logfile already exists")
    print("logging directory: " + str(dir_name))
    logdir = dir_name
    writer = SummaryWriter(logdir=logdir)
    return(writer)

from time import time

#writer = make_writer("Testlog" + str(time())[-4:])

# %%
t.train(50, print_every=1)#, writer=writer)
# Out:
# ----- Epoch: 0 -----
# loss: 1.8634494398534298
# ----- Epoch: 1 -----
# loss: 1.29092503644526
# ----- Epoch: 2 -----
# loss: 1.3559621919319034
# ----- Epoch: 3 -----
# loss: 1.031702435221523
# ----- Epoch: 4 -----
# loss: 0.9323000093549489
# ----- Epoch: 5 -----
# loss: 0.8500389729253948
# ----- Epoch: 6 -----
# loss: 0.7362978383153677
# ----- Epoch: 7 -----
# loss: 0.6795393076539039
# ----- Epoch: 8 -----
# loss: 0.6685366592928768
# ----- Epoch: 9 -----
# loss: 0.6710464371740819
# ----- Epoch: 10 -----
# loss: 0.7038379975035787
# ----- Epoch: 11 -----
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-a27f15289c61> in <module>
# ----> 1 t.train(50, print_every=1)#, writer=writer)
#
# E:\Research\ContrastiveLearning\Code\trainers.py in train(self, epochs, print_every, error_tolerance, writer)
#     108
#     109                 ## Try to train_iter
# --> 110                 batch_loss = self.train_iter((x1,x2), y)
#     111
#     112                 ## If not, hit the exception message, increment error counter
#
# E:\Research\ContrastiveLearning\Code\trainers.py in train_iter(self, input, label, verbose)
#      55         ## Pass the inputs through the model
#      56         x1, x2 = input
# ---> 57         emb1 = self.model(x1); emb2 = self.model(x2)
#      58
#      59         ## Calculate the loss(es)
#
# c:\users\shai9937\appdata\local\continuum\miniconda3\envs\changedetection\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# E:\Research\ContrastiveLearning\Code\models.py in forward(self, x)
#      40         assert (h==w and h==105), "Inputs must be shaped (B, in_channels, 105, 105)"
#      41
# ---> 42         emb = self.backbone(x); b,c,h,w = emb.shape
#      43         emb = emb.view(b, c*h*w)
#      44         emb = self.projector(emb)
#
# c:\users\shai9937\appdata\local\continuum\miniconda3\envs\changedetection\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# c:\users\shai9937\appdata\local\continuum\miniconda3\envs\changedetection\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# c:\users\shai9937\appdata\local\continuum\miniconda3\envs\changedetection\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# c:\users\shai9937\appdata\local\continuum\miniconda3\envs\changedetection\lib\site-packages\torch\nn\modules\pooling.py in forward(self, input)
#     151
#     152     def forward(self, input: Tensor) -> Tensor:
# --> 153         return F.max_pool2d(input, self.kernel_size, self.stride,
#     154                             self.padding, self.dilation, self.ceil_mode,
#     155                             self.return_indices)
#
# c:\users\shai9937\appdata\local\continuum\miniconda3\envs\changedetection\lib\site-packages\torch\_jit_internal.py in fn(*args, **kwargs)
#     265             return if_true(*args, **kwargs)
#     266         else:
# --> 267             return if_false(*args, **kwargs)
#     268
#     269     if if_true.__doc__ is None and if_false.__doc__ is not None:
#
# c:\users\shai9937\appdata\local\continuum\miniconda3\envs\changedetection\lib\site-packages\torch\nn\functional.py in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     583     if stride is None:
#     584         stride = torch.jit.annotate(List[int], [])
# --> 585     return torch.max_pool2d(
#     586         input, kernel_size, stride, padding, dilation, ceil_mode)
#     587
#
# RuntimeError: CUDA out of memory. Tried to allocate 54.00 MiB (GPU 0; 4.00 GiB total capacity; 2.79 GiB already allocated; 26.26 MiB free; 2.88 GiB reserved in total by PyTorch)

# %%
torch.save(M.state_dict(), "model_weights.pth")

# %%
e1 = torch.Tensor([[1,2,3],[2,3,4]])
print(e1.shape)
writer.add_embedding(mat = e1, metadata = ["t1", "t2"])

# %%
import keyword
import torch
meta = []
while len(meta)<100:
    meta = meta+keyword.kwlist # get some strings
meta = meta[:100]

for i, v in enumerate(meta):
    meta[i] = v+str(i)

label_img = torch.rand(100, 3, 32, 32)
for i in range(100):
    label_img[i]*=i/100.0

writer.add_embedding(torch.randn(100, 5), metadata=meta, label_img=label_img)
writer.add_embedding(torch.randn(100, 5), label_img=label_img)
writer.add_embedding(torch.randn(100, 5), metadata=meta)

# %% [markdown]
# $$ L(A, P, N) = \max(||f(A) - f(P)||^2 - ||f(A) - f(N)||^2 + \alpha, 0) $$
#
# $$ D(A,P) < D(A,N) + M $$
#
# $$ D(A,P) = 0, D(A,N) = M $$
